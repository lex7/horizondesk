# %%
from dataclasses import dataclass, asdict, is_dataclass
from typing import List
import random
import json
import pprint
import os
class EnhancedJSONEncoder(json.JSONEncoder): # Класс необходимый для сериализации dataclass (не трогать)
    def default(self, o):
        if is_dataclass(o):
            return asdict(o)
        return super().default(o)
@dataclass
class MonthPerformance:
    name_of_month: str
    done: int
    executing: int
    declined: int

@dataclass
class Region:
    name_of_region: str
    months: List[MonthPerformance]
    total_done: int
    total_executing: int
    total_declined: int

@dataclass
class Fabric:
    regions: List[Region]
    specialization: str


def regions()->List[Region]:
    region_list=[]
    for region in region_quantity:
        months_list = region_per_months()
        region_list.append(Region(region,
                                  months_list,
                                  sum([month.done for month in months_list]),       # total_done
                                  sum([month.executing for month in months_list]),  # total_executing
                                  sum([month.declined for month in months_list])    # total_declined
                                  ))  
    return region_list

def region_per_months()->List[MonthPerformance]:
    months_list = []
    for month in months:
        months_list.append(MonthPerformance(month,
                                            random.randint(8,12), # done        (Можно менять)
                                            random.randint(2,5), # executing   (Можно менять)
                                            random.randint(1,3), # declined    (Можно менять)
                                            ))
    return months_list


specializ = "Инструменты", "Документооборот", "Санитарно-бытовые условия", "Безопасность труда"  # Пример специализации
region_quantity = ["Участок №"+str(i) for i in range(1,4)]                                                                        # Количество цехов
months = ["Март", "Апрель", "Май"]                                                                                                  # Месяца

data = {"Цех 1":Fabric(regions(),random.choice(specializ))}

pprint.pprint(data)
#print(os.getcwd())

with open("data_json_2.json", "w") as write_file:
     json.dump(data, write_file, cls=EnhancedJSONEncoder)
# Out:
# {'Цех 1': Fabric(regions=[Region(name_of_region='Участок №1',
#                                  months=[MonthPerformance(name_of_month='Март',
#                                                           done=9,
#                                                           executing=4,
#                                                           declined=1),
#                                          MonthPerformance(name_of_month='Апрель',
#                                                           done=9,
#                                                           executing=2,
#                                                           declined=1),
#                                          MonthPerformance(name_of_month='Май',
#                                                           done=8,
#                                                           executing=3,
#                                                           declined=3)],
#                                  total_done=26,
#                                  total_executing=9,
#                                  total_declined=5),
#                           Region(name_of_region='Участок №2',
#                                  months=[MonthPerformance(name_of_month='Март',
#                                                           done=9,
#                                                           executing=2,
#                                                           declined=2),
#                                          MonthPerformance(name_of_month='Апрель',
#                                                           done=8,
#                                                           executing=5,
#                                                           declined=2),
#                                          MonthPerformance(name_of_month='Май',
#                                                           done=9,
#                                                           executing=2,
#                                                           declined=3)],
#                                  total_done=26,
#                                  total_executing=9,
#                                  total_declined=7),
#                           Region(name_of_region='Участок №3',
#                                  months=[MonthPerformance(name_of_month='Март',
#                                                           done=11,
#                                                           executing=5,
#                                                           declined=1),
#                                          MonthPerformance(name_of_month='Апрель',
#                                                           done=8,
#                                                           executing=3,
#                                                           declined=1),
#                                          MonthPerformance(name_of_month='Май',
#                                                           done=10,
#                                                           executing=4,
#                                                           declined=2)],
#                                  total_done=29,
#                                  total_executing=12,
#                                  total_declined=4)],
#                  specialization='Санитарно-бытовые условия')}
